# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('houses.txt', sep=" ", header=None)
df.columns = ["LP","MHV","MINC","HAGE","TROOMS","TBEDR","POP","HHDS","LATI","LONGI"]
df = df.drop('LP', 1)
df.head()
# Out:
#         MHV    MINC  HAGE  TROOMS   TBEDR     POP    HHDS   LATI   LONGI
# 0  452600.0  8.3252  41.0   880.0   129.0   322.0   126.0  37.88 -122.23
# 1  358500.0  8.3014  21.0  7099.0  1106.0  2401.0  1138.0  37.86 -122.22
# 2  352100.0  7.2574  52.0  1467.0   190.0   496.0   177.0  37.85 -122.24
# 3  341300.0  5.6431  52.0  1274.0   235.0   558.0   219.0  37.85 -122.25
# 4  342200.0  3.8462  52.0  1627.0   280.0   565.0   259.0  37.85 -122.25

# %% [markdown]
# ### Przypisanie etykiet kolumn do zmiennej columns

# %%
columns=df.columns

# %% [markdown]
# ### Wyświetlenie ilości obserwacji, średniej, odchylenia standardowego, wartości minimalnej, kwartyli Q1,Q2,Q3 oraz wartości maksymalnej dla całego zestawu danych

# %%
df[columns].describe()
# Out:
#                  MHV          MINC          HAGE        TROOMS         TBEDR  \
# count   20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean   206855.816909      3.870671     28.639486   2635.763081    537.898014
# std    115395.615874      1.899822     12.585558   2181.615252    421.247906
# min     14999.000000      0.499900      1.000000      2.000000      1.000000
# 25%    119600.000000      2.563400     18.000000   1447.750000    295.000000
# 50%    179700.000000      3.534800     29.000000   2127.000000    435.000000
# 75%    264725.000000      4.743250     37.000000   3148.000000    647.000000
# max    500001.000000     15.000100     52.000000  39320.000000   6445.000000
#
#                 POP          HHDS          LATI         LONGI
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean    1425.476744    499.539680     35.631861   -119.569704
# std     1132.462122    382.329753      2.135952      2.003532
# ...

# %% [markdown]
# ### Utworzenie zbioru danych składającego się ze zmiennych objaśniających

# %%
df2 = df[['MINC', 'HAGE', 'TROOMS', 'TBEDR', 'POP', 'HHDS', 'LATI', 'LONGI']]
df2.head()
# Out:
#      MINC  HAGE  TROOMS   TBEDR     POP    HHDS   LATI   LONGI
# 0  8.3252  41.0   880.0   129.0   322.0   126.0  37.88 -122.23
# 1  8.3014  21.0  7099.0  1106.0  2401.0  1138.0  37.86 -122.22
# 2  7.2574  52.0  1467.0   190.0   496.0   177.0  37.85 -122.24
# 3  5.6431  52.0  1274.0   235.0   558.0   219.0  37.85 -122.25
# 4  3.8462  52.0  1627.0   280.0   565.0   259.0  37.85 -122.25

# %%
standarize = StandardScaler()
df2 = standarize.fit_transform(df)
df2 = pd.DataFrame(df2)
df2 = df[['MINC', 'HAGE', 'TROOMS', 'TBEDR', 'POP', 'HHDS', 'LATI', 'LONGI']]

# %% [markdown]
# ### Macierz wykresów rozrzutu ustandaryzowanych zmiennych objaśniających wraz z histogramem obrazującym rozkład poszczególnych cech

# %%
sns.pairplot(df2)
